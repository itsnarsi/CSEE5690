# %%
import pandas as pd

import time

import os

from datetime import datetime

# %% [markdown]
# Linux src and dst folder

# %%
src_folder = '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website'
dst_folder = '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/curated_logs'

# %%
def get_filepaths(directory):
    """
    This function will generate the file names in a directory 
    tree by walking the tree either top-down or bottom-up. For each 
    directory in the tree rooted at directory top (including top itself), 
    it yields a 3-tuple (dirpath, dirnames, filenames).
    """
    file_paths = []  # List which will store all of the full filepaths.

    # Walk the tree.
    for root, directories, files in os.walk(directory):
        for filename in files:
            # Join the two strings in order to form the full filepath.
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)  # Add it to the list.

    return file_paths  # Self-explanatory.

# %%
file_path = get_filepaths(src_folder)

# %%
file_path
# Out:
# ['/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Tue, Aug 16, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Tue, Aug 9, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sun, Jul 17, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Wed, Jul 20, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Mon, Jul 25, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Fri, Aug 19, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Mon, Aug 1, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Thu, Jul 21, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Fri, Aug 5, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sun, Jul 24, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Tue, Jul 26, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Thu, Aug 18, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Fri, Jul 29, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Thu, Jul 28, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sat, Aug 6, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sat, Jul 16, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Wed, Aug 17, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Mon, Aug 15, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sun, Aug 7, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Thu, Aug 4, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Wed, Aug 3, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Wed, Aug 10, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Fri, Jul 22, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Tue, Jul 19, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sun, Jul 31, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Mon, Jul 18, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Fri, Aug 12, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sun, Aug 14, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sat, Aug 13, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sat, Jul 23, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Thu, Aug 11, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Mon, Aug 8, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Sat, Jul 30, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Wed, Jul 27, 2016.log',
#  '/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/NetworkRouting-website/NetworkRouting-website/Tue, Aug 2, 2016.log']

# %%
for F in file_path:
    log_data = pd.read_csv(F,' ',header=None, error_bad_lines=False)
    X =  F.split('/') # Spliting the src file path to get only the file name at the end
    file_name = '_'.join(X[-1].split(','))
    day_time = log_data[4].str.split('[')
    Web_Page = log_data[6].str.split(' ')
    print(file_name)
    final_log = pd.DataFrame({'IP' : log_data[1]})
    
    date = []
    time = []
    get_ = []
    url = []
    http = []
    
    len_fl = final_log.shape
    for i in range(len_fl[0]):
        #final_log['date'][i] = day_time[i][1][:11]
        #final_log['time'][i] = day_time[i][1][12:]
        #final_log['get'][i] = Web_Page[i][0]
        #final_log['url'][i] = Web_Page[i][1]
        #final_log['http'][i] = Web_Page[i][2]
        x = Web_Page[i][1].split('.')
        if x[0] in 'www':
            Web_Page[i][1] = Web_Page[i][1][4:]
        
        date.append(day_time[i][1][:11])
        time.append(day_time[i][1][12:])
        get_.append(Web_Page[i][0])
        url.append(Web_Page[i][1])
        http.append(Web_Page[i][2])
    
    
    final_log['date'] = date
    final_log['time'] = time
    final_log['get'] = get_
    final_log['url'] = url
    final_log['http'] = http
    final_log['status'] = log_data[7]
    final_log['size'] = log_data[8]
    final_log['browzer'] = log_data[10]
    final_log.to_csv(dst_folder+'/'+file_name, sep=',', header=False, index=False)
# Out:
# Tue_ Aug 16_ 2016.log
# Tue_ Aug 9_ 2016.log
# Sun_ Jul 17_ 2016.log
# Wed_ Jul 20_ 2016.log
# Mon_ Jul 25_ 2016.log
# Fri_ Aug 19_ 2016.log
# Mon_ Aug 1_ 2016.log
# Thu_ Jul 21_ 2016.log
# Fri_ Aug 5_ 2016.log
# Sun_ Jul 24_ 2016.log
# Tue_ Jul 26_ 2016.log
# Thu_ Aug 18_ 2016.log
# Fri_ Jul 29_ 2016.log
# Thu_ Jul 28_ 2016.log
# Sat_ Aug 6_ 2016.log
# Sat_ Jul 16_ 2016.log
# Wed_ Aug 17_ 2016.log
# Mon_ Aug 15_ 2016.log
# Sun_ Aug 7_ 2016.log
# Thu_ Aug 4_ 2016.log
# Wed_ Aug 3_ 2016.log
# Wed_ Aug 10_ 2016.log
# Fri_ Jul 22_ 2016.log
# Tue_ Jul 19_ 2016.log
# Sun_ Jul 31_ 2016.log
# Mon_ Jul 18_ 2016.log
# Fri_ Aug 12_ 2016.log
# Skipping line 56: expected 11 fields, saw 12
# Skipping line 57: expected 11 fields, saw 12
# Sun_ Aug 14_ 2016.log
# Sat_ Aug 13_ 2016.log
# Sat_ Jul 23_ 2016.log
# Thu_ Aug 11_ 2016.log
# Mon_ Aug 8_ 2016.log
# Sat_ Jul 30_ 2016.log
# Wed_ Jul 27_ 2016.log
# Tue_ Aug 2_ 2016.log

# %%
x = pd.Series.value_counts(final_log['url'])
Y = x.axes[0]

# %%
Y
# Out:
# Index([u'networkrouting.net/docs/mr-chapter_1.pdf',
#        u'networkrouting.net/index.html', u'networkrouting.net/robots.txt',
#        u'networkrouting.net/favicon.ico',
#        u'networkrouting.net/docs/mr-chapter_1.pdf??docs/mr-chapter_1.pdf',
#        u'networkrouting.net/cardioid-figure.php',
#        u'networkrouting.net/incendiaries-joellyn.php', u'networkrouting.net/',
#        u'networkrouting.net/wp-login.php',
#        u'networkrouting.net/robots.txt??robots.txt',
#        u'networkrouting.net/docs/medhi-ramasamy-network-routing-bibliography.pdf',
#        u'networkrouting.net/sm4i.html', u'networkrouting.net/rr.html',
#        u'networkrouting.net/content.html',
#        u'networkrouting.net/course-org.html',
#        u'networkrouting.net/wp-admin/admin-ajax.php',
#        u'networkrouting.net/wp-content/themes/persuasion/lib/scripts/dl-skin.php',
#        u'networkrouting.net/ata.html??ata.html',
#        u'networkrouting.net/wp-content/themes/churchope/lib/downloadlink.php',
#        u'networkrouting.net/wp-content/themes/epic/includes/download.php',
#        u'networkrouting.net/docs/rr.html',
#        u'networkrouting.net/wp-content/themes/FR0_theme/down.php',
#        u'networkrouting.net/refs.html',
#        u'networkrouting.net/wp-content/themes/authentic/includes/download.php',
#        u'networkrouting.net/wp-content/themes/yakimabait/download.php',
#        u'networkrouting.net/wp-content/themes/parallelus-salutation/framework/utilities/download/getfile.php',
#        u'networkrouting.net/wp-content/plugins/wp-filemanager/incl/libfile.php',
#        u'networkrouting.net/user/',
#        u'networkrouting.net/wp-content/plugins/db-backup/download.php',
#        u'networkrouting.net/wp-content/themes/echelon/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/themes/lote27/download.php',
#        u'networkrouting.net/wp-content/themes/felis/download.php',
#        u'networkrouting.net/wp-content/plugins/dukapress/lib/dp_image.php',
#        u'networkrouting.net/wp-content/themes/modular/lib/scripts/dl-skin.php',
#        u'networkrouting.net/docs/rr.html??docs/rr.html',
#        u'networkrouting.net/reviews.html',
#        u'networkrouting.net/wp-content/plugins/ajax-store-locator-wordpress_0/sl_file_download.php',
#        u'networkrouting.net/wp-content/themes/elegance/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/plugins/plugin-newsletter/preview.php',
#        u'networkrouting.net/wp-content/force-download.php',
#        u'networkrouting.net/images/right_unclear.gif',
#        u'networkrouting.net/wp-content/themes/construct/lib/scripts/dl-skin.php',
#        u'networkrouting.net/docs/medhi-ramasamy-network-routing-bibliography.pdf??docs/medhi-ramasamy-network-routing-bibliography.pdf',
#        u'networkrouting.net/wp-content/themes/markant/download.php',
#        u'networkrouting.net/images/network2.jpg',
#        u'networkrouting.net/wp-content/themes/myriad/lib/scripts/dl-skin.php',
#        u'networkrouting.net/sm4i.html??sm4i.html',
#        u'networkrouting.net/wp-content/themes/method/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/themes/jarida/download.php',
#        u'networkrouting.net/wp-content/plugins/tinymce-thumbnail-gallery/php/download-image.php',
#        u'networkrouting.net/wp-content/themes/awake/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/plugins/google-mp3-audio-player/direct_download.php',
#        u'networkrouting.net/docs/NetworkRouting_Chapter_25.pdf',
#        u'networkrouting.net/wp-content/themes/trinity/lib/scripts/download.php',
#        u'networkrouting.net/wp-content/plugins/filedownload/download.php/',
#        u'networkrouting.net/wp-content/themes/antioch/lib/scripts/download.php',
#        u'networkrouting.net/wp-content/themes/infocus/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/themes/dejavu/lib/scripts/dl-skin.php',
#        u'networkrouting.net/administrator/index.php',
#        u'networkrouting.net/wp-content/themes/acento/includes/view-pdf.php',
#        u'networkrouting.net/wp-content/themes/corporate_works/downloader.php',
#        u'networkrouting.net/wp-content/themes/TheLoft/download.php',
#        u'networkrouting.net/docs/NetworkRouting_Chapter_22.pdf',
#        u'networkrouting.net/images/pxl_clr.gif',
#        u'networkrouting.net/wp-content/themes/parallelus-mingle/framework/utilities/download/getfile.php',
#        u'networkrouting.net/wp-content/themes/fusion/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/themes/SMWF/inc/download.php',
#        u'networkrouting.net/wp-content/themes/Newspapertimes_1/download.php',
#        u'networkrouting.net/gutting.html',
#        u'networkrouting.net/wp-content/plugins/pica-photo-gallery/picadownload.php',
#        u'networkrouting.net/modules/productpageadverts/uploadimage.php',
#        u'networkrouting.net/wp-content/themes/urbancity/lib/scripts/download.php',
#        u'networkrouting.net/wp-content/themes/infocus2/lib/scripts/dl-skin.php',
#        u'networkrouting.net/wp-content/themes/linenity/functions/download.php',
#        u'networkrouting.net/wp-content/plugins/simple-download-button-shortcode/simple-download-button_dl.php',
#        u'networkrouting.net/wp-content/themes/NativeChurch/download/download.php',
#        u'networkrouting.net/wp-content/themes/tess/download.php',
#        u'networkrouting.net/ata.html',
#        u'networkrouting.net/wp-content/themes/ypo-theme/download.php',
#        u'networkrouting.net/wp-content/themes/MichaelCanthony/download.php'],
#       dtype='object')

# %%
datetime.strptime('Aug 11_ 2016', '%b %d_ %Y').strftime("%Y-%m-%d")
# Out:
# '2016-08-11'

# %%
result_data = pd.read_csv('/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/result.log','--end--',header=None, error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f7b9bb9223df> in <module>()
# ----> 1 result_data = pd.read_csv('/home/narsi/Documents/CSEE5690_data/A2_WEB_SYS_LOG/result.log','--end--',header=None, error_bad_lines=False)
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     313
#     314     # Create the parser.
# --> 315     parser = TextFileReader(filepath_or_buffer, **kwds)
#     316
#     317     if (nrows is not None) and (chunksize is not None):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     639
#     640         # might mutate self.engine
# --> 641         self.options, self.engine = self._clean_options(options, engine)
#     642         if 'has_index_names' in kwds:
#     643             self.options['has_index_names'] = kwds['has_index_names']
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _clean_options(self, options, engine)
#     735                         msg += " (Note the 'converters' option provides"\
#     736                                " similar functionality.)"
# --> 737                     raise ValueError(msg)
#     738                 del result[arg]
#     739
#
# ValueError: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex), but this causes 'error_bad_lines' to be ignored as it is not supported by the 'python' engine.

# %%
result_data
# Out:
#                                                       0
# 0                                 Fri_ Aug 12_ 2016.log
# 1                                         most Visited:
# 2     networkrouting.net/docs/matta-ieee-commmag-aug...
# 3     networkrouting.net/docs/mr-chapter_1.pdf??docs...
# 4                  networkrouting.net/docs/mr-toc.pdf 1
# 5     networkrouting.net/docs/NetworkRouting_Chapter...
# 6     networkrouting.net/docs/NetworkRouting_Chapter...
# 7     networkrouting.net/docs/NetworkRouting_Chapter...
# 8                    networkrouting.net/foreword.html 1
# 9     networkrouting.net/foreword.html??foreword.html 1
# 10        networkrouting.net/incendiaries-joellyn.php 1
# 11                networkrouting.net/mr-chapter_1.pdf 1
# 12    networkrouting.net/mr-chapter_1.pdf??mr-chapte...
# 13          networkrouting.net/robots.txt??robots.txt 1
# 14            networkrouting.net/sm4i.html??sm4i.html 1
# 15                        networkrouting.net/ata.html 2
# 16    networkrouting.net/docs/medhi-ramasamy-network...
# 17    networkrouting.net/docs/NetworkRouting_Chapter...
# 18    networkrouting.net/docs/NetworkRouting_Chapter...
# 19                     networkrouting.net/errata.html 2
# 20                    networkrouting.net/gutting.html 2
# 21                       networkrouting.net/refs.html 2
# 22             networkrouting.net/images/network2.jpg 3
# 23                    networkrouting.net/reviews.html 3
# 24                         networkrouting.net/rr.html 3
# 25                       networkrouting.net/sm4i.html 3
# 26             networkrouting.net/cardioid-figure.php 4
# 27                                networkrouting.net/ 5
# 28                    networkrouting.net/content.html 6
# 29                 networkrouting.net/course-org.html 6
# ...                                                 ...
# 1826                networkrouting.net/modules/up.php 1
# 1827              networkrouting.net/mr-chapter_1.pdf 1
# 1828  networkrouting.net/mr-chapter_1.pdf??mr-chapte...
# 1829          networkrouting.net/sm4i.html??sm4i.html 1
# 1830           networkrouting.net/cardioid-figure.php 2
# 1831               networkrouting.net/course-org.html 2
# 1832      networkrouting.net/errata.html??errata.html 2
# 1833                 networkrouting.net/foreword.html 2
# 1834           networkrouting.net/images/network2.jpg 2
# 1835      networkrouting.net/incendiaries-joellyn.php 2
# 1836                       networkrouting.net/rr.html 2
# 1837                      networkrouting.net/ata.html 3
# 1838                   networkrouting.net/errata.html 3
# 1839                     networkrouting.net/refs.html 3
# 1840                     networkrouting.net/sm4i.html 3
# 1841                  networkrouting.net/reviews.html 4
# 1842                  networkrouting.net/content.html 5
# 1843                  networkrouting.net/gutting.html 5
# 1844                              networkrouting.net/ 6
# 1845        networkrouting.net/robots.txt??robots.txt 6
# 1846  networkrouting.net/docs/mr-chapter_1.pdf??docs...
# 1847        networkrouting.net/docs/mr-chapter_1.pdf 11
# 1848                  networkrouting.net/favicon.ico 16
# 1849                   networkrouting.net/robots.txt 17
# 1850                   networkrouting.net/index.html 30
# 1851                                       404 numbers:
# 1852                                             404 19
# 1853                                     First chapter:
# 1854                                                 22
# 1855  -------------------------------------------end...
#
# [1856 rows x 1 columns]
